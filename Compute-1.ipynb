# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Importing CSV file using Pandas and displaying 5 rows

# %%
df = pd.read_csv("C:/MLCourse/Databaseforml/spotifydata.csv")
df.head()
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0        0.0102         0.833       204600   0.434
# 1           1        0.1990         0.743       326933   0.359
# 2           2        0.0344         0.838       185707   0.412
# 3           3        0.6040         0.494       199413   0.338
# 4           4        0.1800         0.678       392893   0.561
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# 2          0.000234    2    0.1590    -7.148     1       0.2890   75.044
# 3          0.510000    5    0.0922   -15.236     1       0.0261   86.468
# 4          0.512000    5    0.4390   -11.648     0       0.0694  174.004
#
#    time_signature  valence  target      song_title            artist
# 0             4.0    0.286       1        Mask Off            Future
# ...

# %% [markdown]
# Displaying top 10 rows

# %%
df.head(10)
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0       0.01020         0.833       204600   0.434
# 1           1       0.19900         0.743       326933   0.359
# 2           2       0.03440         0.838       185707   0.412
# 3           3       0.60400         0.494       199413   0.338
# 4           4       0.18000         0.678       392893   0.561
# 5           5       0.00479         0.804       251333   0.560
# 6           6       0.01450         0.739       241400   0.472
# 7           7       0.02020         0.266       349667   0.348
# 8           8       0.04810         0.603       202853   0.944
# 9           9       0.00208         0.836       226840   0.603
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# ...

# %% [markdown]
# Displaying bottom 5 rows

# %%
df.tail()
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 2012          0.002690    1    0.1290    -3.501     1        0.333   74.976
# 2013          0.001670    1    0.0528    -2.663     1        0.131  110.041
# 2014          0.003990    0    0.2140    -2.467     1        0.107  150.082
# 2015          0.677000    1    0.0913    -2.735     1        0.133  150.011
# 2016          0.000039    9    0.2180    -6.221     1        0.141  190.013
#
#       time_signature  valence  target                            song_title  \
# ...

# %% [markdown]
# Displaying bottom 10 rows

# %%
df.tail(10)
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 2007        2007      0.002170         0.639       296276   0.978
# 2008        2008      0.054100         0.646       160408   0.714
# 2009        2009      0.004990         0.595       224000   0.837
# 2010        2010      0.002310         0.624       206013   0.971
# 2011        2011      0.000586         0.528       245053   0.879
# 2012        2012      0.001060         0.584       274404   0.932
# 2013        2013      0.087700         0.894       182182   0.892
# 2014        2014      0.008570         0.637       207200   0.935
# 2015        2015      0.001640         0.557       185600   0.992
# 2016        2016      0.002810         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 2007          0.112000   11    0.0838    -2.376     1       0.0730  144.986
# 2008          0.000000    0    0.1340    -6.511     1       0.0378   97.957
# ...

# %% [markdown]
# Using .info function to have a look at the Data type and null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2017 non-null   int64
#  1   acousticness      2017 non-null   float64
#  2   danceability      2017 non-null   float64
#  3   duration_ms       2017 non-null   int64
#  4   energy            2017 non-null   float64
#  5   instrumentalness  2017 non-null   float64
#  6   key               2017 non-null   int64
#  7   liveness          2017 non-null   float64
#  8   loudness          2017 non-null   float64
#  9   mode              2017 non-null   int64
#  10  speechiness       2017 non-null   float64
#  11  tempo             2017 non-null   float64
#  12  time_signature    2017 non-null   float64
#  13  valence           2017 non-null   float64
#  14  target            2017 non-null   int64
#  15  song_title        2017 non-null   object
# ...

# %% [markdown]
# Sorting on basis of danceability and displaying top 10 song title

# %%
df.sort_values('danceability')[['song_title']].head(10)
# Out:
#                                              song_title
# 729                                          Bumpy Road
# 532                                     Wake Bake Skate
# 817   Mozart: Requiem in D Minor, K. 626: VIII. Lacr...
# 1600         Trio Sonata in G Major, Wq. 144: I. Adagio
# 1598  Piano Quartet in E flat, Op.47: 3. Andante can...
# 522                                               Outro
# 1348               Be My Valentine (feat. Dickie Allen)
# 1464                                         Right Here
# 1313                                    Senseless Order
# 1306                                               Ruin

# %% [markdown]
# Same as previous one, just displaying an extra column artist

# %%
df.sort_values('danceability')[['song_title', 'artist']].head(10)
# Out:
#                                              song_title  \
# 729                                          Bumpy Road
# 532                                     Wake Bake Skate
# 817   Mozart: Requiem in D Minor, K. 626: VIII. Lacr...
# 1600         Trio Sonata in G Major, Wq. 144: I. Adagio
# 1598  Piano Quartet in E flat, Op.47: 3. Andante can...
# 522                                               Outro
# 1348               Be My Valentine (feat. Dickie Allen)
# 1464                                         Right Here
# 1313                                    Senseless Order
# 1306                                               Ruin
#
#                          artist
# 729            Destruction Unit
# 532                      FIDLAR
# 817        Nikolaus Harnoncourt
# 1600  Carl Philipp Emanuel Bach
# 1598            Robert Schumann
# 522                         M83
# 1348                     Brojob
# 1464              Keys N Krates
# 1313         Signs of the Swarm
# ...

# %% [markdown]
# Sorting on basis of duration of song and displaying top 10 song title, artists and duration

# %%
df.sort_values('duration_ms')[['song_title','artist','duration_ms']].head(10)
# Out:
#                                    song_title            artist  duration_ms
# 1044             Zac Brown Band - Hot Country   Various Artists        16042
# 1436                               dance alot   Various Artists        16588
# 1591                       Little Green Apple       Tumble Tots        47547
# 1583                         Peas Pudding Hot     The Kids Band        51547
# 936                                     Aloha        Chris Bear        52006
# 1530                   I'm a Fool to Want You  Passport Quartet        66762
# 1594  Lyric Pieces, Book I Op. 12: I. Arietta      Edvard Grieg        82293
# 804                  Just Wanna Love You Girl          Epsilons        82893
# 1593                    Icy, Creamy Ice Cream            Barney        87705
# 533                                    No Ass            FIDLAR        93267

# %% [markdown]
# Creating a new dataframe and storing only those values which have duration less than 400000 ms

# %%
temp_df = df[df['duration_ms']<400000]

# %% [markdown]
# Sorting new dataframe in ascending on basis of energy and displaying  bottom 10

# %%
temp_df2 = temp_df.sort_values('energy')[['song_title','artist','duration_ms','energy']].tail(10)
temp_df2.head()
# Out:
#                song_title               artist  duration_ms  energy
# 1296         Black Colors  Victim Of Deception       247533   0.990
# 1681                Hated            Beartooth       211430   0.990
# 1328  Down into the Abyss          Conjonctive       256920   0.991
# 1680             Paranoia    A Day To Remember       200677   0.992
# 1332      Beautiful Agony     Within The Ruins       271560   0.992

# %% [markdown]
# Sorting values on basis of energy in descending order

# %%
ans = temp_df2.sort_values('energy', ascending=False)

# %% [markdown]
# Sorting on basis of duration and exporting CSV file

# %%
df_filtered = df.sort_values('duration_ms')[['song_title', 'artist', 'duration_ms']].tail(10)
df_filtered.to_csv('D:\ML Files\spotify_filtered_data.csv')

# %% [markdown]
# keeping only that data which has energ value greater than 0.4, only keeping song title and artists

# %%
temp_df = df[df['energy']>0.4]
temp_df[['song_title','artist']].head(10)
# Out:
#                               song_title              artist
# 0                               Mask Off              Future
# 2                           Xanny Family              Future
# 4                         Parallel Lines         Junior Boys
# 5                               Sneakin’               Drake
# 6                            Childs Play               Drake
# 8                      I've Seen Footage         Death Grips
# 9                         Digital Animal         Honey Claws
# 10  Subways - In Flagranti Extended Edit      The Avalanches
# 11            Donme Dolap - Baris K Edit  Modern Folk Üçlüsü
# 12                               Cemalim         Erkin Koray

# %% [markdown]
# keeping only that data, in which duration is greater than 3000000

# %%
temp_df = df[df['duration_ms']>300000]

# %% [markdown]
# Sorting on basis of tempo column and displaying top 10

# %%
temp_df2 = temp_df.sort_values('tempo',ascending = False)[['song_title','artist']].head(10)
temp_df2.head()
# Out:
#                                              song_title            artist
# 412                                              Lazuli       Beach House
# 942                                            Remember       Gino Soccio
# 729                                          Bumpy Road  Destruction Unit
# 1560                       Emperor Jones - Instrumental        Joe Lovano
# 992   Swerve... the reeping of all that is worthwhil...   Shabazz Palaces

# %% [markdown]
# Keeping only those rows, with Drake as artist and energy greater than 0.5

# %%
temp_df = df[df['artist'] == 'Drake']

# %%
temp_df2 = temp_df[temp_df['energy']>0.5]

# %%
temp_df2[['song_title']].head(10)
# Out:
#                    song_title
# 5                    Sneakin’
# 37                    Jumpman
# 117             Hotline Bling
# 154                 Big Rings
# 440                 Headlines
# 589   Started From the Bottom
# 779   0 To 100 / The Catch Up
# 1016         Skepta Interlude
# 1218          Best I Ever Had
# 1223                Take Care

# %% [markdown]
# Sort values in descending order on basis of instrumentalness

# %%
temp_df = df.sort_values('instrumentalness',ascending = False)[['song_title','artist','instrumentalness']]
temp_df.head(10)
# Out:
#                                 song_title                    artist  \
# 1313                       Senseless Order        Signs of the Swarm
# 271   So Destroyed (channeling Rage Peace)               Prince Rama
# 1575             A Hundred Dreams from Now                Ray Bryant
# 1619                                 Raven             John Dahlbäck
# 725                      Strandbar (disko)                Todd Terje
# 1546                        Almas vaggvisa         Jan Lundgren Trio
# 1322                            Pitchblack  Walking Dead On Broadway
# 1349                       Prismatic Abyss           Aversions Crown
# 1661                               Yebisah               Mark Knight
# 121                         Chasing Heaven                Bassnectar
#
#       instrumentalness
# 1313             0.976
# 271              0.968
# 1575             0.964
# 1619             0.958
# 725              0.957
# 1546             0.956
# 1322             0.955
# ...
